# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Assignment 5
#
# Zhi Kai Chen
# 20728525

# %%
with open("V_HO_1_1") as f:
    data = f.read()

data = data.split('\n')

x = []
y = []
for i in range(len(data)-1):
    x.append(float(data[i].split(' ')[0]))
    y.append(float(data[i].split(' ')[1]))

# %% [markdown]
# ## Question 1: Harmonic Oscillator

# %% [markdown]
# ### a) Plot harmonic oscillator potential

# %%
plt.figure(figsize = (15,6))
plt.plot(x, y)
 
# naming the x axis
#plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('Potential')
 
# giving a title to my graph
plt.title('Harmonic Oscillator Potential')
 
# function to show the plot
plt.show()

# %% [markdown]
# The reason why the potential stays the same for all possible combinations of beta and tau is because the potential is the not a function of beta or tau.

# %% [markdown]
# ### b) Plot convergence of the free energy

# %% [markdown]
# #### i.  ii.  &  iii.
#
# $\beta = 1, 5, 10$

# %%
hbar = 1
omega = 1


beta_vals = list(range(1,256))

free_energy_vals = []
for beta in beta_vals:
    free_energy_vals.append(-np.log(1./(2.*np.sinh(beta*hbar*omega/2.)))/beta)

# %%
plt.plot(beta_vals, free_energy_vals)
 
# naming the x axis
plt.xlabel('Beta')
# naming the y axis
plt.ylabel('Free Energy')
 
# giving a title to my graph
plt.title('Free Energy vs Beta')
 
plt.show()

# %% [markdown]
# The free energy converges at a value of 0.5

# %%
# For beta = 1 and Grid Size = 101
z_analytical_101 = [0.9595173756674719, 0.9595173756674719, 
                0.9595173756674719, 0.9595173756674719,
               0.9595173756674719]
a_analytical_101 = [0.041324854612918106, 0.041324854612918106,
               0.041324854612918106, 0.041324854612918106,
               0.041324854612918106]

tau = [1.0, 0.25, 0.0625, 0.015625, 0.00390625]

z_path_integral_101 = [1.0000000000000002, 0.9622088501465871,
                  0.9596863018937805, 1.0243399432769156,
                  8.941731098227575e+28]
a_path_integral_101 = [-2.2204460492503128e-16, 0.038523751934736034,
                  0.04114881678147805, -0.02404844738188673,
                  -66.66311180942233]

z_sos_101 = [0.959517375667473, 0.959517375667473,
        0.959517375667473, 0.959517375667473,
        0.959517375667473]
a_sos_101 = [0.04132485461291695, 0.04132485461291695,
        0.04132485461291695, 0.04132485461291695,
        0.04132485461291695]

# For beta = 1 and grid size = 501

z_analytical_501 = [0.9595173756674719, 0.9595173756674719, 
                0.9595173756674719, 0.9595173756674719,
               0.9595173756674719]
a_analytical_501 = [0.041324854612918106, 0.041324854612918106, 
                0.041324854612918106, 0.041324854612918106,
               0.041324854612918106]

z_path_integral_501 = [1.0000000000000004, 0.9622088501465866,
                  0.9596863018838248, 0.9595279363480465,
                  0.9595180357209382]
a_path_integral_501 = [-4.440892098500625e-16, 0.0385237519347365,
                  0.04114881679185196, 0.04131384843134587,
                  0.041324166711629355]

z_sos_501 = [0.9595173756679397, 0.9595173756679397,
        0.9595173756679397, 0.9595173756679397,
        0.9595173756679397]
a_sos_501 = [0.04132485461243052, 0.04132485461243052,
        0.04132485461243052, 0.04132485461243052,
        0.04132485461243052]

# %% [markdown]
# It seems that increasing the P value does not have a significant effect on the computational cost. However, going from grid size 101 to grid size 501 there is a significant increase in computational cost.

# %%
# For beta = 5 and Grid Size = 101
z_analytical_101 = [0.08264183492754779, 0.08264183492754779]
a_analytical_101 = [0.49864785011010226, 0.49864785011010226]

tau = [1.0, 0.25, 0.0625, 0.015625, 0.00390625]

z_path_integral_101 = [0.20000000000000004]
a_path_integral_101 = [0.32188758248682003]

z_sos_101 = [0.08264183492754781]
a_sos_101 = [0.4986478501101022]

# %% [markdown]
# ### c) Plot diagonal density matrix

# %% [markdown]
# #### i.  ii.  &  iii.
#
# $\beta = 1, 5, 10$

# %%
with open("Harmonic_Oscillator/density/501/rho_HO_1.0_1.0_501") as f:
    data_HO_tau_1 = f.read()

data_HO_tau_1 = data_HO_tau_1.split('\n')

x_tau_1 = []
y_tau_1 = []
for i in range(len(data_HO_tau_1)-1):
    x_tau_1.append(float(data_HO_tau_1[i].split(' ')[0]))
    y_tau_1.append(float(data_HO_tau_1[i].split(' ')[1]))
    
with open("Harmonic_Oscillator/density/501/rho_HO_1.0_0.25_501") as f:
    data_HO_p_4 = f.read()

data_HO_p_4 = data_HO_p_4.split('\n')

x_p_4 = []
y_p_4 = []
for i in range(len(data_HO_p_4)-1):
    x_p_4.append(float(data_HO_p_4[i].split(' ')[0]))
    y_p_4.append(float(data_HO_p_4[i].split(' ')[1]))
    
with open("Harmonic_Oscillator/density/501/rho_HO_1.0_0.0625_501") as f:
    data_HO_p_16 = f.read()

data_HO_p_16 = data_HO_p_16.split('\n')

x_p_16 = []
y_p_16 = []
for i in range(len(data_HO_p_16)-1):
    x_p_16.append(float(data_HO_p_16[i].split(' ')[0]))
    y_p_16.append(float(data_HO_p_16[i].split(' ')[1]))
    
with open("Harmonic_Oscillator/density/501/rho_HO_1.0_0.015625_501") as f:
    data_HO_p_64 = f.read()

data_HO_p_64 = data_HO_p_64.split('\n')

x_p_64 = []
y_p_64 = []
for i in range(len(data_HO_p_64)-1):
    x_p_64.append(float(data_HO_p_64[i].split(' ')[0]))
    y_p_64.append(float(data_HO_p_64[i].split(' ')[1]))
    
with open("Harmonic_Oscillator/density/501/rho_HO_1.0_0.00390625_501") as f:
    data_HO_p_256 = f.read()

data_HO_p_256 = data_HO_p_256.split('\n')

x_p_256 = []
y_p_256 = []
for i in range(len(data_HO_p_256)-1):
    x_p_256.append(float(data_HO_p_256[i].split(' ')[0]))
    y_p_256.append(float(data_HO_p_256[i].split(' ')[1]))

# %%
fig, axs = plt.subplots(3,1, figsize = (15,15))

axs[0].plot(x_tau_1, y_tau_1, label = "Tau: 1")
axs[0].plot(x_p_4, y_p_4, label = 'Tau: 0.25')
axs[0].plot(x_p_16, y_p_16, label = 'Tau: 0.0625')
axs[0].plot(x_p_64, y_p_64, label = 'Tau: 0.015625')
axs[0].plot(x_p_256, y_p_256, label = 'Tau: 0.00390625')

axs[0].set_title("i. Beta = 1")
axs[0].legend()


axs[1].plot(x_b5_p1, y_b5_p1, label = "Tau: 5")
axs[1].plot(x_b5_p4, y_b5_p4, label = 'Tau: 1.25')
axs[1].plot(x_b5_p16, y_b5_p16, label = 'Tau: 0.3125')
axs[1].plot(x_b5_p64, y_b5_p64, label = 'Tau: 0.078125')
axs[1].plot(x_b5_p256, y_b5_p256, label = 'Tau: 0.01953125')

axs[1].set_title("ii. Beta = 5")
axs[1].legend()



axs[2].plot(x_b10_p1, y_b10_p1, label = "Tau: 10")
axs[2].plot(x_b10_p4, y_b10_p4, label = 'Tau: 2.5')
axs[2].plot(x_b10_p16, y_b10_p16, label = 'Tau: 0.625')
axs[2].plot(x_b10_p64, y_b10_p64, label = 'Tau: 0.15625')
axs[2].plot(x_b10_p256, y_b10_p256, label = 'Tau: 0.0390625')

axs[2].set_title("iii. Beta = 10")
axs[2].legend()


for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# Below are the same graphs, but zoomed in.

# %%
fig, axs = plt.subplots(3,1, figsize = (15,15))

axs[0].axis(xmin = -2.5, xmax = 2.5, ymin = 0.35, ymax = 0.4)

axs[0].plot(x_tau_1, y_tau_1, label = "Tau: 1")
axs[0].plot(x_p_4, y_p_4, label = 'Tau: 0.25')
axs[0].plot(x_p_16, y_p_16, label = 'Tau: 0.0625')
axs[0].plot(x_p_64, y_p_64, label = 'Tau: 0.015625')
axs[0].plot(x_p_256, y_p_256, label = 'Tau: 0.00390625')

axs[0].set_title("i. Beta = 1 (Zoomed In)")
axs[0].legend()

axs[1].axis(xmin = -2.5, xmax = 2.5, ymin = 0.4, ymax = 0.6)

axs[1].plot(x_b5_p1, y_b5_p1, label = "Tau: 5")
axs[1].plot(x_b5_p4, y_b5_p4, label = 'Tau: 1.25')
axs[1].plot(x_b5_p16, y_b5_p16, label = 'Tau: 0.3125')
axs[1].plot(x_b5_p64, y_b5_p64, label = 'Tau: 0.078125')
axs[1].plot(x_b5_p256, y_b5_p256, label = 'Tau: 0.01953125')

axs[1].set_title("ii. Beta = 5 (Zoomed In)")
axs[1].legend()


axs[2].axis(xmin = -2.5, xmax = 2.5, ymin = 0.4, ymax = 0.6)

axs[2].plot(x_b10_p1, y_b10_p1, label = "Tau: 10")
axs[2].plot(x_b10_p4, y_b10_p4, label = 'Tau: 2.5')
axs[2].plot(x_b10_p16, y_b10_p16, label = 'Tau: 0.625')
axs[2].plot(x_b10_p64, y_b10_p64, label = 'Tau: 0.15625')
axs[2].plot(x_b10_p256, y_b10_p256, label = 'Tau: 0.0390625')

axs[2].set_title("iii. Beta = 10 (Zoomed In)")
axs[2].legend()


for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# Increasing the beta value increases the tau value because tau is equal to beta divided p. We can see that as beta and tau increases, the y-values increase as well. Also, as beta and tau increases, the graphs become more narrow horizontally. This can be seen by observing the blue line. For beta = 1 and tau = 1, the graph begins to rise at x = -2.5 and becomes flat again at x = 2.5, whereas for beta = 1 and tau = 10, the graph begins to rise at around x = -1 and becomes flat again at x = 1.

# %%
with open("Harmonic_Oscillator/density/501/rho_HO_10.0_10.0") as f:
    data_HO_b10_p1 = f.read()

data_HO_b10_p1 = data_HO_b10_p1.split('\n')

x_b10_p1 = []
y_b10_p1 = []
for i in range(len(data_HO_b10_p1)-1):
    x_b10_p1.append(float(data_HO_b10_p1[i].split(' ')[0]))
    y_b10_p1.append(float(data_HO_b10_p1[i].split(' ')[1]))
    
with open("Harmonic_Oscillator/density/501/rho_HO_10.0_2.5") as f:
    data_HO_b10_p4 = f.read()

data_HO_b10_p4 = data_HO_b10_p4.split('\n')

x_b10_p4 = []
y_b10_p4 = []
for i in range(len(data_HO_b10_p4)-1):
    x_b10_p4.append(float(data_HO_b10_p4[i].split(' ')[0]))
    y_b10_p4.append(float(data_HO_b10_p4[i].split(' ')[1]))
    
with open("Harmonic_Oscillator/density/501/rho_HO_10.0_0.625") as f:
    data_HO_b10_p16 = f.read()

data_HO_b10_p16 = data_HO_b10_p16.split('\n')

x_b10_p16 = []
y_b10_p16 = []
for i in range(len(data_HO_b10_p16)-1):
    x_b10_p16.append(float(data_HO_b10_p16[i].split(' ')[0]))
    y_b10_p16.append(float(data_HO_b10_p16[i].split(' ')[1]))
    
with open("Harmonic_Oscillator/density/501/rho_HO_10.0_0.15625") as f:
    data_HO_b10_p64 = f.read()

data_HO_b10_p64 = data_HO_b10_p64.split('\n')

x_b10_p64 = []
y_b10_p64 = []
for i in range(len(data_HO_b10_p64)-1):
    x_b10_p64.append(float(data_HO_b10_p64[i].split(' ')[0]))
    y_b10_p64.append(float(data_HO_b10_p64[i].split(' ')[1]))
    
with open("Harmonic_Oscillator/density/501/rho_HO_10.0_0.0390625") as f:
    data_HO_b10_p256 = f.read()

data_HO_b10_p256 = data_HO_b10_p256.split('\n')

x_b10_p256 = []
y_b10_p256 = []
for i in range(len(data_HO_b10_p256)-1):
    x_b10_p256.append(float(data_HO_b10_p256[i].split(' ')[0]))
    y_b10_p256.append(float(data_HO_b10_p256[i].split(' ')[1]))

# %% [markdown]
# ## Question 2: Double Well

# %% [markdown]
# ### a) Plot Double Well Potential

# %%
with open("V_DW_1.0_1.0") as f:
    data_dw = f.read()

data_dw = data_dw.split('\n')

x = []
y = []
for i in range(len(data_dw)-1):
    x.append(float(data_dw[i].split(' ')[0]))
    y.append(float(data_dw[i].split(' ')[1]))

# %%
plt.figure(figsize = (15,6))
plt.plot(x, y)
 
# naming the x axis
#plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('Potential')
 
# giving a title to my graph
plt.title('Double Well Potential')
 
# function to show the plot
plt.show()

# %% [markdown]
# The reason why the potential stays the same for all possible combinations of beta and tau is because the potential is the not a function of beta or tau.

# %% [markdown]
# ### b) Plot Convergence of the free energy

# %% [markdown]
# #### i.  ii.  &  iii.
#
# $\beta = 1, 5, 10$

# %% [markdown]
# In the code there is no equation for free energy of Double Well?
#
# It seems that increasing the P value does not have a significant effect on the computational cost. However, going from grid size 101 to grid size 501 there is a significant increase in computational cost.

# %%
hbar = 1
omega = 1


beta_vals = list(range(1,256))

free_energy_vals = []
for beta in beta_vals:
    free_energy_vals.append(-np.log(1./(2.*np.sinh(beta*hbar*omega/2.)))/beta)

# %% [markdown]
# ### c) Plot diagonal density matrix

# %%
with open("Double_Well/density/501/rho_DW_1.0_1.0") as f:
    data_DW_b1_p1 = f.read()

data_DW_b1_p1 = data_DW_b1_p1.split('\n')

x_DW_b1_p1 = []
y_DW_b1_p1 = []
for i in range(len(data_DW_b1_p1)-1):
    x_DW_b1_p1.append(float(data_DW_b1_p1[i].split(' ')[0]))
    y_DW_b1_p1.append(float(data_DW_b1_p1[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_1.0_0.25") as f:
    data_DW_b1_p4 = f.read()

data_DW_b1_p4 = data_DW_b1_p4.split('\n')

x_DW_b1_p4 = []
y_DW_b1_p4 = []
for i in range(len(data_DW_b1_p4)-1):
    x_DW_b1_p4.append(float(data_DW_b1_p4[i].split(' ')[0]))
    y_DW_b1_p4.append(float(data_DW_b1_p4[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_1.0_0.0625") as f:
    data_DW_b1_p16 = f.read()

data_DW_b1_p16 = data_DW_b1_p16.split('\n')

x_DW_b1_p16 = []
y_DW_b1_p16 = []
for i in range(len(data_DW_b1_p16)-1):
    x_DW_b1_p16.append(float(data_DW_b1_p16[i].split(' ')[0]))
    y_DW_b1_p16.append(float(data_DW_b1_p16[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_1.0_0.015625") as f:
    data_DW_b1_p64 = f.read()

data_DW_b1_p64 = data_DW_b1_p64.split('\n')

x_DW_b1_p64 = []
y_DW_b1_p64 = []
for i in range(len(data_DW_b1_p64)-1):
    x_DW_b1_p64.append(float(data_DW_b1_p64[i].split(' ')[0]))
    y_DW_b1_p64.append(float(data_DW_b1_p64[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_1.0_0.00390625") as f:
    data_DW_b1_p256 = f.read()

data_DW_b1_p256 = data_DW_b1_p256.split('\n')

x_DW_b1_p256 = []
y_DW_b1_p256 = []
for i in range(len(data_DW_b1_p256)-1):
    x_DW_b1_p256.append(float(data_DW_b1_p256[i].split(' ')[0]))
    y_DW_b1_p256.append(float(data_DW_b1_p256[i].split(' ')[1]))

# %%
with open("Double_Well/density/501/rho_DW_5.0_5.0") as f:
    data_DW_b5_p1 = f.read()

data_DW_b5_p1 = data_DW_b5_p1.split('\n')

x_DW_b5_p1 = []
y_DW_b5_p1 = []
for i in range(len(data_DW_b5_p1)-1):
    x_DW_b5_p1.append(float(data_DW_b5_p1[i].split(' ')[0]))
    y_DW_b5_p1.append(float(data_DW_b5_p1[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_5.0_1.25") as f:
    data_DW_b5_p4 = f.read()

data_DW_b5_p4 = data_DW_b5_p4.split('\n')

x_DW_b5_p4 = []
y_DW_b5_p4 = []
for i in range(len(data_DW_b5_p4)-1):
    x_DW_b5_p4.append(float(data_DW_b5_p4[i].split(' ')[0]))
    y_DW_b5_p4.append(float(data_DW_b5_p4[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_5.0_0.3125") as f:
    data_DW_b5_p16 = f.read()

data_DW_b5_p16 = data_DW_b5_p16.split('\n')

x_DW_b5_p16 = []
y_DW_b5_p16 = []
for i in range(len(data_DW_b5_p16)-1):
    x_DW_b5_p16.append(float(data_DW_b5_p16[i].split(' ')[0]))
    y_DW_b5_p16.append(float(data_DW_b5_p16[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_5.0_0.078125") as f:
    data_DW_b5_p64 = f.read()

data_DW_b5_p64 = data_DW_b5_p64.split('\n')

x_DW_b5_p64 = []
y_DW_b5_p64 = []
for i in range(len(data_DW_b5_p64)-1):
    x_DW_b5_p64.append(float(data_DW_b5_p64[i].split(' ')[0]))
    y_DW_b5_p64.append(float(data_DW_b5_p64[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_5.0_0.01953125") as f:
    data_DW_b5_p256 = f.read()

data_DW_b5_p256 = data_DW_b5_p256.split('\n')

x_DW_b5_p256 = []
y_DW_b5_p256 = []
for i in range(len(data_DW_b5_p256)-1):
    x_DW_b5_p256.append(float(data_DW_b5_p256[i].split(' ')[0]))
    y_DW_b5_p256.append(float(data_DW_b5_p256[i].split(' ')[1]))

# %%
with open("Double_Well/density/501/rho_DW_10.0_10.0") as f:
    data_DW_b10_p1 = f.read()

data_DW_b10_p1 = data_DW_b10_p1.split('\n')

x_DW_b10_p1 = []
y_DW_b10_p1 = []
for i in range(len(data_DW_b10_p1)-1):
    x_DW_b10_p1.append(float(data_DW_b10_p1[i].split(' ')[0]))
    y_DW_b10_p1.append(float(data_DW_b10_p1[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_10.0_2.5") as f:
    data_DW_b10_p4 = f.read()

data_DW_b10_p4 = data_DW_b10_p4.split('\n')

x_DW_b10_p4 = []
y_DW_b10_p4 = []
for i in range(len(data_DW_b10_p4)-1):
    x_DW_b10_p4.append(float(data_DW_b10_p4[i].split(' ')[0]))
    y_DW_b10_p4.append(float(data_DW_b10_p4[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_10.0_0.625") as f:
    data_DW_b10_p16 = f.read()

data_DW_b10_p16 = data_DW_b10_p16.split('\n')

x_DW_b10_p16 = []
y_DW_b10_p16 = []
for i in range(len(data_DW_b10_p16)-1):
    x_DW_b10_p16.append(float(data_DW_b10_p16[i].split(' ')[0]))
    y_DW_b10_p16.append(float(data_DW_b10_p16[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_10.0_0.15625") as f:
    data_DW_b10_p64 = f.read()

data_DW_b10_p64 = data_DW_b10_p64.split('\n')

x_DW_b10_p64 = []
y_DW_b10_p64 = []
for i in range(len(data_DW_b10_p64)-1):
    x_DW_b10_p64.append(float(data_DW_b10_p64[i].split(' ')[0]))
    y_DW_b10_p64.append(float(data_DW_b10_p64[i].split(' ')[1]))
    
with open("Double_Well/density/501/rho_DW_10.0_0.0390625") as f:
    data_DW_b10_p256 = f.read()

data_DW_b10_p256 = data_DW_b10_p256.split('\n')

x_DW_b10_p256 = []
y_DW_b10_p256 = []
for i in range(len(data_DW_b10_p256)-1):
    x_DW_b10_p256.append(float(data_DW_b10_p256[i].split(' ')[0]))
    y_DW_b10_p256.append(float(data_DW_b10_p256[i].split(' ')[1]))

# %%
fig, axs = plt.subplots(3,1, figsize = (15,15))

axs[0].plot(x_DW_b1_p1, y_DW_b1_p1, label = "Tau: 1")
axs[0].plot(x_DW_b1_p4, y_DW_b1_p4, label = 'Tau: 0.25')
axs[0].plot(x_DW_b1_p16, y_DW_b1_p16, label = 'Tau: 0.0625')
axs[0].plot(x_DW_b1_p64, y_DW_b1_p64, label = 'Tau: 0.015625')
axs[0].plot(x_DW_b1_p256, y_DW_b1_p256, label = 'Tau: 0.00390625')

axs[0].set_title("i. Beta = 1")
axs[0].legend()


axs[1].plot(x_DW_b5_p1, y_DW_b5_p1, label = "Tau: 5")
axs[1].plot(x_DW_b5_p4, y_DW_b5_p4, label = 'Tau: 1.25')
axs[1].plot(x_DW_b5_p16, y_DW_b5_p16, label = 'Tau: 0.3125')
axs[1].plot(x_DW_b5_p64, y_DW_b5_p64, label = 'Tau: 0.078125')
axs[1].plot(x_DW_b5_p256, y_DW_b5_p256, label = 'Tau: 0.01953125')

axs[1].set_title("i. Beta = 5")
axs[1].legend()


axs[2].plot(x_DW_b10_p1, y_DW_b10_p1, label = "Tau: 10")
axs[2].plot(x_DW_b10_p4, y_DW_b10_p4, label = 'Tau: 2.5')
axs[2].plot(x_DW_b10_p16, y_DW_b10_p16, label = 'Tau: 0.625')
axs[2].plot(x_DW_b10_p64, y_DW_b10_p64, label = 'Tau: 0.15625')
axs[2].plot(x_DW_b10_p256, y_DW_b10_p256, label = 'Tau: 0.0390625')

axs[2].set_title("i. Beta = 10")
axs[2].legend()


for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# Below are the same graphs, but zoomed in.

# %%
fig, axs = plt.subplots(3,1, figsize = (15,15))

axs[0].axis(xmin = -2.5, xmax = 2.5, ymin = 0.10, ymax = 0.20)

axs[0].plot(x_DW_b1_p1, y_DW_b1_p1, label = "Tau: 1")
axs[0].plot(x_DW_b1_p4, y_DW_b1_p4, label = 'Tau: 0.25')
axs[0].plot(x_DW_b1_p16, y_DW_b1_p16, label = 'Tau: 0.0625')
axs[0].plot(x_DW_b1_p64, y_DW_b1_p64, label = 'Tau: 0.015625')
axs[0].plot(x_DW_b1_p256, y_DW_b1_p256, label = 'Tau: 0.00390625')

axs[0].set_title("i. Beta = 1 (Zoomed In)")
axs[0].legend()

axs[1].axis(xmin = -2.5, xmax = 2.5, ymin = 0.10, ymax = 0.25)

axs[1].plot(x_DW_b5_p1, y_DW_b5_p1, label = "Tau: 5")
axs[1].plot(x_DW_b5_p4, y_DW_b5_p4, label = 'Tau: 1.25')
axs[1].plot(x_DW_b5_p16, y_DW_b5_p16, label = 'Tau: 0.3125')
axs[1].plot(x_DW_b5_p64, y_DW_b5_p64, label = 'Tau: 0.078125')
axs[1].plot(x_DW_b5_p256, y_DW_b5_p256, label = 'Tau: 0.01953125')

axs[1].set_title("i. Beta = 5 (Zoomed In)")
axs[1].legend()

axs[2].axis(xmin = -2.5, xmax = 2.5, ymin = 0.2, ymax = 0.3)

axs[2].plot(x_DW_b10_p1, y_DW_b10_p1, label = "Tau: 10")
axs[2].plot(x_DW_b10_p4, y_DW_b10_p4, label = 'Tau: 2.5')
axs[2].plot(x_DW_b10_p16, y_DW_b10_p16, label = 'Tau: 0.625')
axs[2].plot(x_DW_b10_p64, y_DW_b10_p64, label = 'Tau: 0.15625')
axs[2].plot(x_DW_b10_p256, y_DW_b10_p256, label = 'Tau: 0.0390625')

axs[2].set_title("i. Beta = 10 (Zoomed In)")
axs[2].legend()


for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# Increasing the beta value increases the tau value because tau is equal to beta divided p. We can see that as beta and tau increases, the y-values increase as well. Also, as beta and tau increases, the graphs become more narrow horizontally because the descent to the local minimum is much steeper causing a wider local minimum.
